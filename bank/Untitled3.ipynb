# %%
from flask import Flask, request
import pickle

app = Flask(__name__)
model = pickle.load(open("model.pkl", "rb"))

@app.route('/')
def home():
    return "Flask is running"

@app.route('/predict', methods=['POST'])
def predict():
    data = [[
        int(request.form['age']),
        int(request.form['job']),
        int(request.form['marital']),
        int(request.form['education']),
        int(request.form['balance']),
        int(request.form['campaign'])
    ]]
    return str(model.predict(data)[0])

if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\rutva\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
